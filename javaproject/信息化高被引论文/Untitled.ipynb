# %%
import pandas as pd

# %%
pd.set_option('display.max_columns', 500)

# %%
data = pd.read_csv("数据1.txt", sep="\t")
data
# Out:
#     PT                                                 AU  BA   BE  GP  \
# 0    J                            Li, GQ; Xue, Q; Qin, JH NaN  NaN NaN
# 1    J                   Law, R; Buhalis, D; Cobanoglu, C NaN  NaN NaN
# 2    J  Gardner, RL; Cooper, E; Haskell, J; Harris, DA... NaN  NaN NaN
# 3    J                                 Irfan, M; Ahmad, M NaN  NaN NaN
# 4    J                        Lee, CC; Yuan, ZH; Wang, QR NaN  NaN NaN
# ..  ..                                                ...  ..  ...  ..
# 995  J  Yang, YH; Yamagami, Y; Yu, XB; Pitchappa, P; W... NaN  NaN NaN
# 996  J                      Hasin, Y; Seldin, M; Lusis, A NaN  NaN NaN
# 997  J  Tang, CL; He, ZY; Liu, HM; Xu, YY; Huang, H; Y... NaN  NaN NaN
# 998  J  Yassin, A; Nasser, Y; Awad, M; Al-Dubai, A; Li... NaN  NaN NaN
# 999  J                                 Moqbel, M; Kock, N NaN  NaN NaN
#
#                                                     AF  BF   CA  \
# ...
